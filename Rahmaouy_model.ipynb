# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")
train_text = train["TEXT"].astype(str)
train_label = train["LABEL"]

# TF-IDF features
vectorizer =TfidfVectorizer(lowercase=True,ngram_range=(1, 3),min_df=3,sublinear_tf=True)
F_train =vectorizer.fit_transform(train_text)
# Logistic Regression model
model = LogisticRegression(max_iter=5000, class_weight="balanced",C=20.0,solver="liblinear")
model.fit(F_train, train_label)

#predictions 
test_text =test["TEXT"].astype(str)
F_test = vectorizer.transform(test_text)
predictions = model.predict(F_test)

submit = pd.DataFrame({"ID": test_D["ID"],"LABEL":predictions})
#submit.to_csv("/Users/fedouarahmaouy/Desktop/14submission.csv", index=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:1288: FutureWarning: Using the 'liblinear' solver for multiclass classification is deprecated. An error will be raised in 1.8. Either use another solver which supports the multinomial loss or wrap the estimator in a OneVsRestClassifier to keep applying a one-versus-rest scheme.
#   warnings.warn(
